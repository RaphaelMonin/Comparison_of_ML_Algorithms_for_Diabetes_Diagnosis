# %% [markdown]
# ## Import the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn import svm
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# ## Import the data

# %%
ds = pd.read_csv('diabetes.csv')

# %% [markdown]
# ## Analyse the data

# %%
ds.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
hist = ds.hist(figsize=(15,15))

# %% [markdown]
# ## Split the data

# %%
X_train, X_test, y_train, y_test = train_test_split(ds.drop(['Outcome'], axis=1),ds.Outcome)
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((576, 8), (576,), (192, 8), (192,))

# %% [markdown]
# ## Normalize the data

# %%
from sklearn import preprocessing

scaler = preprocessing.StandardScaler().fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# # SVM

# %% [markdown]
# ## Preprocess, Train and Test a SVM Model with a polynomial kernel

# %% [markdown]
# ### Find the best hyperparameters degree and C

# %%
scores = []
degrees = list(map(lambda x: x, range(0,8)))
for deg in degrees:
    svc = svm.SVC(kernel='poly', degree=deg)
    svc.fit(X_train_scaled,y_train)
    scores.append(svc.score(X_test_scaled,y_test))
plt.plot(degrees, scores)
plt.show()

# %%
scores = []
Cs = list(map(lambda x: 10**x, range(-2,3)))
for c in Cs:
    svc = svm.SVC(kernel='poly', degree=1, C=c)
    svc.fit(X_train_scaled,y_train)
    scores.append(svc.score(X_test_scaled,y_test))
plt.semilogx(Cs, scores)
plt.show()

# %% [markdown]
# ### Train and test

# %%
svc = svm.SVC(kernel='poly', degree=1, C=1)
svc.fit(X_train_scaled,y_train)
print('Accuracy on testing dataset: ', round(svc.score(X_test_scaled,y_test), 2))
# Out:
# Accuracy on testing dataset:  0.79

# %% [markdown]
# ## Preprocess, Train and Test a SVM Model with a rbf kernel

# %% [markdown]
# ### Find the best hyperparameters C and gamma

# %%
np.random.seed(0) 
scores = []
Cs = list(map(lambda x: 10**x, range(-2,3)))
for c in Cs:
    svc = svm.SVC(C=c)
    svc.fit(X_train_scaled,y_train)
    scores.append(svc.score(X_test_scaled,y_test))
plt.semilogx(Cs, scores)
plt.show()

# %%
scores = []
gammas = list(map(lambda x: 10**x, range(-5,6)))
for gamma in gammas:
    svc = svm.SVC(C=1, gamma=gamma)
    svc.fit(X_train_scaled,y_train)
    scores.append(svc.score(X_test_scaled,y_test))
plt.semilogx(gammas, scores)
plt.show()

# %% [markdown]
# ### Train and test

# %%
svc = svm.SVC(C=1, gamma=0.01)
svc.fit(X_train_scaled,y_train)
print('Accuracy on testing dataset: ', round(svc.score(X_test_scaled,y_test), 2))
# Out:
# Accuracy on testing dataset:  0.79

# %% [markdown]
# # Naive Bayes

# %% [markdown]
# ## Train and test the Gaussian Naive Bayes Model

# %%
np.random.seed(0) 
gnb = GaussianNB()
gnb.fit(X_train,y_train)
print('Accuracy on testing dataset: ', round(gnb.score(X_test, y_test), 2))
# Out:
# Accuracy on testing dataset:  0.78

# %% [markdown]
# # KNN

# %% [markdown]
# ## Find the best hyperparameter k

# %%
np.random.seed(0) 
scores = []
Ks = range(1,30)
for k in Ks:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train,y_train)
    scores.append(knn.score(X_test,y_test))
plt.plot(Ks, scores)
plt.show()

# %% [markdown]
# ## Train and test the K-Nearest Neigbors Model

# %%
np.random.seed(0) 
knn = KNeighborsClassifier(n_neighbors=7)
knn.fit(X_train,y_train)
print('Accuracy on testing dataset: ', round(knn.score(X_test, y_test), 2))
# Out:
# Accuracy on testing dataset:  0.74
